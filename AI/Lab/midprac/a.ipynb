# %%
import pandas as pd
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('./50_Startups.csv')
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend     Profit
# 0  165349.20       136897.80        471784.10  192261.83
# 1  162597.70       151377.59        443898.53  191792.06
# 2  153441.51       101145.55        407934.54  191050.39
# 3  144372.41       118671.85        383199.62  182901.99
# 4  142107.34        91391.77        366168.42  166187.94

# %%
from sklearn.model_selection import train_test_split

xtrain , xtest , ytrain , ytest = train_test_split(
    df[['R&D Spend' , 'Administration',	'Marketing Spend']] ,
    df['Profit'],random_state=3,test_size=0.33)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(xtrain,ytrain)
y_hat = model.predict(xtest)

# %%
import matplotlib.pyplot as plt

# %%
coef = model.coef_
slop = model.intercept_

# %%
from sklearn.metrics import r2_score

# %%
lr = r2_score(ytest,y_hat)
lr
# Out:
# 0.9171689177141273

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model = DecisionTreeRegressor( )
model.fit (xtrain,ytrain)
y_hat = model.predict(xtest)

# %%
rsdt = r2_score(ytest,y_hat)
rsdt
# Out:
# 0.887457786616965

# %%
from sklearn.tree import plot_tree
plot_tree(model)
# Out:
# [Text(0.5411931818181818, 0.9375, 'x[0] <= 90538.43\nsquared_error = 1704639608.751\nsamples = 33\nvalue = 114535.826'),
#  Text(0.2471590909090909, 0.8125, 'x[0] <= 37384.175\nsquared_error = 619867484.307\nsamples = 21\nvalue = 89449.957'),
#  Text(0.39417613636363635, 0.875, 'True  '),
#  Text(0.06818181818181818, 0.6875, 'x[0] <= 657.73\nsquared_error = 427699541.791\nsamples = 8\nvalue = 63487.219'),
#  Text(0.045454545454545456, 0.5625, 'squared_error = 0.0\nsamples = 1\nvalue = 14681.4'),
#  Text(0.09090909090909091, 0.5625, 'x[0] <= 8410.595\nsquared_error = 99900220.193\nsamples = 7\nvalue = 70459.479'),
#  Text(0.06818181818181818, 0.4375, 'squared_error = 0.0\nsamples = 1\nvalue = 49490.75'),
#  Text(0.11363636363636363, 0.4375, 'x[2] <= 156235.906\nsquared_error = 31055450.077\nsamples = 6\nvalue = 73954.267'),
#  Text(0.06818181818181818, 0.3125, 'x[1] <= 141094.219\nsquared_error = 7052667.139\nsamples = 3\nvalue = 68819.267'),
#  Text(0.045454545454545456, 0.1875, 'x[1] <= 111785.965\nsquared_error = 756473.76\nsamples = 2\nvalue = 70628.735'),
#  Text(0.022727272727272728, 0.0625, 'squared_error = 0.0\nsamples = 1\nvalue = 71498.49'),
#  Text(0.06818181818181818, 0.0625, 'squared_error = 0.0\nsamples = 1\nvalue = 69758.98'),
#  Text(0.09090909090909091, 0.1875, 'squared_error = -0.0\nsamples = 1\nvalue = 65200.33'),
#  Text(0.1590909090909091, 0.3125, 'x[1] <= 75329.352\nsquared_error = 2321783.016\nsamples = 3\nvalue = 79089.267'),
#  Text(0.13636363636363635, 0.1875, 'squared_error = 0.0\nsamples = 1\nvalue = 81229.06'),
#  Text(0.18181818181818182, 0.1875, 'x[0] <= 28323.625\nsquared_error = 48637.892\nsamples = 2\nvalue = 78019.37'),
#  Text(0.1590909090909091, 0.0625, 'squared_error = 0.0\nsamples = 1\nvalue = 77798.83'),
#  Text(0.20454545454545456, 0.0625, 'squared_error = 0.0\nsamples = 1\nvalue = 78239.91'),
#  Text(0.42613636363636365, 0.6875, 'x[0] <= 73051.082\nsquared_error = 68049437.952\nsamples = 13\nvalue = 105427.027'),
#  Text(0.3522727272727273, 0.5625, 'x[0] <= 64507.168\nsquared_error = 8567003.098\nsamples = 7\nvalue = 99049.944'),
#  Text(0.29545454545454547, 0.4375, 'x[0] <= 58744.215\nsquared_error = 1624551.226\nsamples = 5\nvalue = 97467.332'),
#  Text(0.25, 0.3125, 'x[1] <= 94052.465\nsquared_error = 16493.603\nsamples = 3\nvalue = 96657.077'),
#  Text(0.22727272727272727, 0.1875, 'squared_error = 0.0\nsamples = 1\nvalue = 96479.51'),
#  Text(0.2727272727272727, 0.1875, 'x[2] <= 212716.242\nsquared_error = 1092.964\nsamples = 2\nvalue = 96745.86'),
#  Text(0.25, 0.0625, 'squared_error = 0.0\nsamples = 1\nvalue = 96712.8'),
#  Text(0.29545454545454547, 0.0625, 'squared_error = -0.0\nsamples = 1\nvalue = 96778.92'),
#  Text(0.3409090909090909, 0.3125, 'x[1] <= 122430.445\nsquared_error = 1574711.266\nsamples = 2\nvalue = 98682.715'),
#  Text(0.3181818181818182, 0.1875, 'squared_error = 0.0\nsamples = 1\nvalue = 99937.59'),
#  Text(0.36363636363636365, 0.1875, 'squared_error = 0.0\nsamples = 1\nvalue = 97427.84'),
#  Text(0.4090909090909091, 0.4375, 'x[2] <= 230161.098\nsquared_error = 4007343.367\nsamples = 2\nvalue = 103006.475'),
#  Text(0.38636363636363635, 0.3125, 'squared_error = 0.0\nsamples = 1\nvalue = 101004.64'),
#  Text(0.4318181818181818, 0.3125, 'squared_error = -0.0\nsamples = 1\nvalue = 105008.31'),
#  Text(0.5, 0.5625, 'x[2] <= 67025.031\nsquared_error = 34648010.568\nsamples = 6\nvalue = 112866.957'),
#  Text(0.4772727272727273, 0.4375, 'squared_error = 0.0\nsamples = 1\nvalue = 122776.86'),
#  Text(0.5227272727272727, 0.4375, 'x[2] <= 219619.641\nsquared_error = 18008128.503\nsamples = 5\nvalue = 110884.976'),
#  Text(0.4772727272727273, 0.3125, 'x[0] <= 76186.438\nsquared_error = 1985985.562\nsamples = 2\nvalue = 107142.79'),
#  Text(0.45454545454545453, 0.1875, 'squared_error = 0.0\nsamples = 1\nvalue = 105733.54'),
#  Text(0.5, 0.1875, 'squared_error = 0.0\nsamples = 1\nvalue = 108552.04'),
#  Text(0.5681818181818182, 0.3125, 'x[1] <= 118325.023\nsquared_error = 13129605.953\nsamples = 3\nvalue = 113379.767'),
#  Text(0.5454545454545454, 0.1875, 'squared_error = 0.0\nsamples = 1\nvalue = 118474.03'),
#  Text(0.5909090909090909, 0.1875, 'x[1] <= 138278.094\nsquared_error = 230769.748\nsamples = 2\nvalue = 110832.635'),
#  Text(0.5681818181818182, 0.0625, 'squared_error = 0.0\nsamples = 1\nvalue = 110352.25'),
#  Text(0.6136363636363636, 0.0625, 'squared_error = -0.0\nsamples = 1\nvalue = 111313.02'),
#  Text(0.8352272727272727, 0.8125, 'x[2] <= 373030.5\nsquared_error = 574480560.198\nsamples = 12\nvalue = 158436.098'),
#  Text(0.6882102272727273, 0.875, '  False'),
#  Text(0.7613636363636364, 0.6875, 'x[2] <= 297093.797\nsquared_error = 130570935.647\nsamples = 8\nvalue = 142903.362'),
#  Text(0.6818181818181818, 0.5625, 'x[2] <= 253128.734\nsquared_error = 66321475.761\nsamples = 5\nvalue = 135654.282'),
#  Text(0.6363636363636364, 0.4375, 'x[0] <= 101292.52\nsquared_error = 867273.126\nsamples = 2\nvalue = 145190.675'),
#  Text(0.6136363636363636, 0.3125, 'squared_error = 0.0\nsamples = 1\nvalue = 144259.4'),
#  Text(0.6590909090909091, 0.3125, 'squared_error = 0.0\nsamples = 1\nvalue = 146121.95'),
#  Text(0.7272727272727273, 0.4375, 'x[2] <= 272175.273\nsquared_error = 8910064.795\nsamples = 3\nvalue = 129296.687'),
#  Text(0.7045454545454546, 0.3125, 'x[1] <= 139582.133\nsquared_error = 1803125.268\nsamples = 2\nvalue = 131259.845'),
#  Text(0.6818181818181818, 0.1875, 'squared_error = 0.0\nsamples = 1\nvalue = 129917.04'),
#  Text(0.7272727272727273, 0.1875, 'squared_error = -0.0\nsamples = 1\nvalue = 132602.65'),
#  Text(0.75, 0.3125, 'squared_error = 0.0\nsamples = 1\nvalue = 125370.37'),
#  Text(0.8409090909090909, 0.5625, 'x[1] <= 147124.508\nsquared_error = 4101510.589\nsamples = 3\nvalue = 154985.163'),
#  Text(0.8181818181818182, 0.4375, 'x[2] <= 343369.031\nsquared_error = 383482.948\nsamples = 2\nvalue = 156371.86'),
#  Text(0.7954545454545454, 0.3125, 'squared_error = 0.0\nsamples = 1\nvalue = 155752.6'),
#  Text(0.8409090909090909, 0.3125, 'squared_error = 0.0\nsamples = 1\nvalue = 156991.12'),
#  Text(0.8636363636363636, 0.4375, 'squared_error = -0.0\nsamples = 1\nvalue = 152211.77'),
#  Text(0.9090909090909091, 0.6875, 'x[2] <= 395567.078\nsquared_error = 14704669.819\nsamples = 4\nvalue = 189501.568'),
#  Text(0.8863636363636364, 0.5625, 'squared_error = 0.0\nsamples = 1\nvalue = 182901.99'),
#  Text(0.9318181818181818, 0.5625, 'x[2] <= 425916.531\nsquared_error = 248705.013\nsamples = 3\nvalue = 191701.427'),
#  Text(0.9090909090909091, 0.4375, 'squared_error = 0.0\nsamples = 1\nvalue = 191050.39'),
#  Text(0.9545454545454546, 0.4375, 'x[2] <= 457841.312\nsquared_error = 55170.963\nsamples = 2\nvalue = 192026.945'),
#  Text(0.9318181818181818, 0.3125, 'squared_error = 0.0\nsamples = 1\nvalue = 191792.06'),
#  Text(0.9772727272727273, 0.3125, 'squared_error = -0.0\nsamples = 1\nvalue = 192261.83')]

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(random_state=3)

# %%
model.fit(xtrain,ytrain)
y_hat = model.predict(xtest)

# %%
msem3 = mean_squared_error(ytest , y_hat)
msem3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 3
#       1 msem3 = mean_squared_error(ytest , y_hat)
#       2 msem3
# ----> 3 mads= mean_squared_error(ytrain , ytest)
#
# File ~/miniconda3/envs/ncomp-env/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~/miniconda3/envs/ncomp-env/lib/python3.11/site-packages/sklearn/metrics/_regression.py:579, in mean_squared_error(y_true, y_pred, sample_weight, multioutput)
#     529 """Mean squared error regression loss.
#     530
#     531 Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)    575 0.825...
#     576 """
#     577 xp, _ = get_namespace(y_true, y_pred, sample_weight, multioutput)
#     578 _, y_true, y_pred, sample_weight, multioutput = (
# --> 579     _check_reg_targets_with_floating_dtype(
#     580         y_true, y_pred, sample_weight, multioutput, xp=xp
#     581     )
#     582 )
#     583 output_errors = _average(
#     584     (y_true - y_pred) ** 2, axis=0, weights=sample_weight, xp=xp
#     585 )
#     587 if isinstance(multioutput, str):
#
# File ~/miniconda3/envs/ncomp-env/lib/python3.11/site-packages/sklearn/metrics/_regression.py:208, in _check_reg_targets_with_floating_dtype(y_true, y_pred, sample_weight, multioutput, xp)
#     159 """Ensures y_true, y_pred, and sample_weight correspond to same regression task.
#     160
#     161 Extends `_check_reg_targets` by automatically selecting a suitable floating-point
#    (...)    204     correct keyword.
#     205 """
#     206 dtype_name = _find_matching_floating_dtype(y_true, y_pred, sample_weight, xp=xp)
# --> 208 y_type, y_true, y_pred, sample_weight, multioutput = _check_reg_targets(
#     209     y_true, y_pred, sample_weight, multioutput, dtype=dtype_name, xp=xp
#     210 )
#     212 return y_type, y_true, y_pred, sample_weight, multioutput
#
# File ~/miniconda3/envs/ncomp-env/lib/python3.11/site-packages/sklearn/metrics/_regression.py:113, in _check_reg_targets(y_true, y_pred, sample_weight, multioutput, dtype, xp)
#      62 """Check that y_true, y_pred and sample_weight belong to the same regression task.
#      63
#      64 To reduce redundancy when calling `_find_matching_floating_dtype`,
#    (...)    109     correct keyword.
#     110 """
#     111 xp, _ = get_namespace(y_true, y_pred, multioutput, xp=xp)
# --> 113 check_consistent_length(y_true, y_pred, sample_weight)
#     114 y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     115 y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# File ~/miniconda3/envs/ncomp-env/lib/python3.11/site-packages/sklearn/utils/validation.py:464, in check_consistent_length(*arrays)
#     462 lengths = [_num_samples(X) for X in arrays if X is not None]
#     463 if len(set(lengths)) > 1:
# --> 464     raise ValueError(
#     465         "Found input variables with inconsistent numbers of samples: %r"
#     466         % [int(l) for l in lengths]
#     467     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [33, 17]
