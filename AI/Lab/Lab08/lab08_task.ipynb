# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn as sk
from sklearn.metrics import mean_squared_error, r2_score

# %%
df=pd.read_csv("Housing.csv")
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0       79545.45857             5.682861                   7.009188
# 1       79248.64245             6.002900                   6.730821
# 2       61287.06718             5.865890                   8.512727
# 3       63345.24005             7.188236                   5.586729
# 4       64698.46343             6.025336                   8.147760
#
#    Avg. Area Number of Bedrooms  Area Population        Price
# 0                          4.09      23086.80050  1059033.558
# 1                          3.09      40173.07217  1505890.915
# 2                          5.13      36882.15940  1058987.988
# 3                          3.26      34310.24283  1260616.807
# 4                          3.41      60828.24909  1502055.817

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0          79545.45857             5.682861                   7.009188
# 1          79248.64245             6.002900                   6.730821
# 2          61287.06718             5.865890                   8.512727
# 3          63345.24005             7.188236                   5.586729
# 4          64698.46343             6.025336                   8.147760
# ...                ...                  ...                        ...
# 4993       60567.94414             7.830362                   6.137356
# 4994       78491.27543             6.999135                   6.576763
# 4995       63390.68689             7.250591                   4.805081
# 4996       68001.33124             5.534388                   7.130144
# 4997       65510.58180             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population        Price
# 0                             4.09      23086.80050  1059033.558
# 1                             3.09      40173.07217  1505890.915
# 2                             5.13      36882.15940  1058987.988
# 3                             3.26      34310.24283  1260616.807
# 4                             3.41      60828.24909  1502055.817
# ...                            ...              ...          ...
# 4993                          3.46      22837.36103  1060193.786
# 4994                          4.02      25616.11549  1482617.729
# 4995                          2.13      33266.14549  1030729.583
# 4996                          5.44      42625.62016  1198656.872
# 4997                          4.07      46501.28380  1298950.480
#
# [4998 rows x 6 columns]>

# %%
df.dropna(inplace=True)

# %%
X = df[["Avg. Area House Age"]]   # independent variable
y = df["Price"]    # dependent variable

model = sk.linear_model.LinearRegression()

model.fit(X, y)
# Out:
# LinearRegression()

# %%
new_size = np.array([[1300]])
predicted_price = model.predict(new_size)

print(f"Predicted price for 1300 sqft house: {predicted_price[0]:,.0f}")
# Out:
# Predicted price for 1300 sqft house: 209,687,624
# /home/muhammad-ahmad/miniconda3/envs/ncomp-env/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(X, y)
plt.plot(X, model.predict(X))
plt.xlabel("Size (sqft)")
plt.ylabel("Price")
plt.title("House Price Prediction")
plt.legend(["fa23-bce-113"])
plt.show()
