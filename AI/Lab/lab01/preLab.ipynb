# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
values = np.random.randn(100)
plt.plot(values)
plt.title('random noice using test program')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
# Out:
# Text(0, 0.5, 'y-axis')

# %% [markdown]
# ## In-Lab Task1

# %%
print ('Hello World \nMy name is Muhammad Ahmad\nMy Registration FA23-BCE-113\nMy First AI Lab')
# Out:
# Hello World
# My name is Muhammad Ahmad
# My Registration FA23-BCE-113
# My First AI Lab

# %% [markdown]
# ## In-Lab Task3

# %%
x=1
if x == 1 :
    print ('x is 1')
# Out:
# x is 1

# %% [markdown]
# ## In-Lab Task4

# %% [markdown]
# ## Numbers

# %% [markdown]
# ### Integers

# %%
# 1. Integers
print ('print value of integer')
integer_us = 7
print (integer_us)
print ('class of integer is')
print (type(integer_us))
# Out:
# print value of integer
# 7
# class of integer is
# <class 'int'>

# %% [markdown]
# ### Floats

# %%
# 2. Float
print ('print value of float')
float_us = 7.1
print (float_us)
print ('class of float is')
print (type(float_us))
# Out:
# print value of float
# 7.1
# class of float is
# <class 'float'>

# %% [markdown]
# ### Convert float to int

# %%
print ('convert value of float to int')
my_int = int (3.4)
print(my_int)
# Out:
# convert value of float to int
# 3

# %% [markdown]
# ## Strings

# %%
mystring = "Hello, World!"
print(mystring)

# and demonstrating how to use an apostrophe in a string
mystring = "Let's talk about apostrophes..."
print(mystring)
# Out:
# Hello, World!
# Let's talk about apostrophes...

# %%
# Assign strings as variables
one = 1
two = 2
three = one + two
print(three)
# Out:
# 3

# %%
hello = "Hello,"
world = "World!"
helloworld = hello + " " + world
print(helloworld)
# Out:
# Hello, World!

# %%
# assign multiple variables simultaneously
a, b = 3, 4
print(a, b)
# Out:
# 3 4

# %%
# Mixing different data variables
lis = list[one, two, hello]
lis
# Out:
# list[1, 2, 'Hello,']

# %%
print(str(one)+ ' ' + str(two)+ ' '  + hello)
# Out:
# 1 2 Hello,

# %% [markdown]
# ## Lists

# %%
mylist = []
mylist.append(1)
mylist.append(2)
mylist.append(3)

# Each item in a list can be addressed directly.
# The first address in a Python list starts at 0
print(mylist[0])

# The last item in a Python list can be addressed as -1.
# This is helpful when you don't know how long a list is likely to be.
print(mylist[-1])

# You can also select subsets of the data in a list like this
print(mylist[1:3])

# You can also loop through a list using a `for` statement.
# Note that `x` is a new variable which takes on the value of
# each item in the list in order.
for i in mylist:
    print (i)
# Out:
# 1
# 3
# [2, 3]
# 1
# 2
# 3

# %%
# Let's imagine we have a list of unordered names that somehow got some random
# numbers included.
# we want to print the alphabetised list of names without the numbers.

names = ["John", 3234, 2342, 3323, "Eric", 234, "Jessica",
         734978234, "Lois", 2384]

print("Number of names in list: {}".format(len(names)))
print("Number of names in list:", (len(names)))
# Out:
# Number of names in list: 10
# Number of names in list: 10

# %%
# First, let's get rid of all the weird integers.
new_names = []

for n in names:
    if isinstance(n, str):
        # Checking if n is a string
        # And note how we're now indented twice into this new component
        new_names.append(n)

# %%
# We should now have only names in the new list. Let's sort them.
new_names.sort()

print("Cleaned-up number of names in list: {}".format(len(new_names)))
# Out:
# Cleaned-up number of names in list: 4

# %%
# Lastly, let's print them.
for i, n in enumerate(new_names): # enumerate combine index and its content
    # Using both i and n in a format
    # Adding 1 to i because lists start at 0
    #print("{}. {}".format(i+1, n))
    print(f"{i+1}. {n}")
# Out:
# 1. Eric
# 2. Jessica
# 3. John
# 4. Lois

# %%
for i, n in enumerate(new_names, start=1):
    print(i , n)
# Out:
# 1 Eric
# 2 Jessica
# 3 John
# 4 Lois

# %%
l = ['ahmad',1]
l
# Out:
# ['ahmad', 1]
